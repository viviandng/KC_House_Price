# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
from statsmodels.formula.api import ols

from scipy.stats import stats

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Lasso, Ridge, LinearRegression

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from yellowbrick.datasets import load_concrete
from yellowbrick.regressor import ResidualsPlot

#from sklearn.feature_selection import RFE

# %%
df = pd.read_csv('../../mod-2-project/data/kc_house_data_2.csv', index_col=0)

# %%
display(df.dtypes)
display(df.shape)
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront       float64
# view             float64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement    float64
# yr_built           int64
# yr_renovated     float64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object
# (21534, 21)

# %% [markdown]
# ### Correlation Analysis

# %%
price_corr = df.corr()['price']
top_price_corr = price_corr[abs(price_corr) > 0.50].sort_values(ascending=False)

# %%
top_price_corr
# Out:
# price            1.000000
# sqft_living      0.701587
# grade            0.668307
# sqft_above       0.605695
# sqft_living15    0.585304
# bathrooms        0.525053
# Name: price, dtype: float64

# %%
def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f',
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70})
    plt.show();

# %%
correlation_heatmap(df)

# %% [markdown]
# ### Log Transformation

# %%
data_log = pd.DataFrame([])
data_log['log_price'] = np.log(df['price'])
df['log_sqft_above'] = np.log(df['sqft_above'])
df['log_sqft_living15'] = np.log(df['sqft_living15'])

df = df.drop(['sqft_above'], axis = 1) 
df = df.drop(['sqft_living15'], axis = 1)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10686d690>]],
#       dtype=object)

# %% [markdown]
# ### Decomposing Categories

# %%
# Excluding price for encoding
x_cols = df.iloc[:, 3:]
x_cols = list(x_cols.columns.values)

# %%
categorical_variables = ['zipcode']

# %%
df_ohe = pd.get_dummies(df[x_cols], columns= categorical_variables, drop_first = True )

# %% [markdown]
# ### Modeling

# %%
## This time note that we are using all of the independent variables 'TV', 'Newspaper', 'Radio'
X = df_ohe.values

## Target variable (Dependent Variable) is still 'Sales' column
y = data_log.log_price.values

## We need to add constants for the intercept term
Xconst = sm.add_constant(X)

## Note that the rest is exactly the same with the simple linear regression
model = sm.OLS(y, Xconst, hasconst= True)
multiple_model_fitted = model.fit()
print(multiple_model_fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.881
# Method:                 Least Squares   F-statistic:                     1858.
# Date:                Mon, 30 Mar 2020   Prob (F-statistic):               0.00
# Time:                        17:04:02   Log-Likelihood:                 6248.6
# No. Observations:               21534   AIC:                        -1.232e+04
# Df Residuals:                   21447   BIC:                        -1.163e+04
# Df Model:                          86
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.759e-05    3.4e-06     -8.109      0.000   -3.43e-05   -2.09e-05
# x1            -0.0086      0.002     -4.831      0.000      -0.012      -0.005
# x2             0.0350      0.003     11.747      0.000       0.029       0.041
# x3          8.406e-05   5.96e-06     14.097      0.000    7.24e-05    9.57e-05
# x4          6.195e-07   4.34e-08     14.280      0.000    5.34e-07    7.05e-07
# x5            -0.0469      0.004    -12.907      0.000      -0.054      -0.040
# x6             0.4740      0.017     28.422      0.000       0.441       0.507
# x7             0.0588      0.002     29.990      0.000       0.055       0.063
# x8             0.0552      0.002     25.401      0.000       0.051       0.059
# x9             0.0899      0.002     43.845      0.000       0.086       0.094
# x10         4.656e-05   6.72e-06      6.931      0.000    3.34e-05    5.97e-05
# x11           -0.0281      0.003     -8.177      0.000      -0.035      -0.021
# x12         3.615e-05   3.62e-06      9.992      0.000    2.91e-05    4.32e-05
# x13            0.5113      0.072      7.133      0.000       0.371       0.652
# x14           -0.3323      0.051     -6.453      0.000      -0.433      -0.231
# x15         9.113e-08   6.83e-08      1.334      0.182   -4.28e-08    2.25e-07
# x16           -0.0276      0.003     -8.040      0.000      -0.034      -0.021
# x17            0.2776      0.012     23.093      0.000       0.254       0.301
# x70            0.3434      0.021     16.264      0.000       0.302       0.385
# x71            0.7677      0.029     26.219      0.000       0.710       0.825
# x72            0.6374      0.026     24.390      0.000       0.586       0.689
# x73            0.3505      0.032     10.936      0.000       0.288       0.413
# x74            0.4051      0.022     18.228      0.000       0.362       0.449
# x75            0.2189      0.033      6.614      0.000       0.154       0.284
# x76            0.5311      0.023     23.315      0.000       0.486       0.576
# x77            0.5164      0.024     21.242      0.000       0.469       0.564
# x78            0.1594      0.020      7.844      0.000       0.120       0.199
# x79            0.0674      0.028      2.445      0.015       0.013       0.121
# x80            0.1899      0.034      5.522      0.000       0.123       0.257
# x81            0.2019      0.019     10.865      0.000       0.165       0.238
# x82           -0.0174      0.020     -0.884      0.377      -0.056       0.021
# x83            0.3235      0.035      9.371      0.000       0.256       0.391
# x84            0.0637      0.020      3.143      0.002       0.024       0.103
# x85            0.0267      0.021      1.284      0.199      -0.014       0.067
# x86            0.0032      0.016      0.201      0.840      -0.028       0.034
# x87            0.6365      0.029     22.309      0.000       0.581       0.692
# ==============================================================================
# Omnibus:                     1663.605   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7476.443
# Skew:                          -0.252   Prob(JB):                         0.00
# Kurtosis:                       5.842   Cond. No.                     3.71e+20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.99e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# #### 88% of the variance in Price are explained by the independent variables in our model.

# %% [markdown]
# ### Stepwise selection with p-values

# %% [markdown]
# [With help from this stackexchange post](https://datascience.stackexchange.com/questions/937/does-scikit-learn-have-forward-selection-stepwise-regression-algorithm

# %%
def stepwise_selection(X, y, 
                       initial_list=[], 
                       threshold_in=0.01, 
                       threshold_out = 0.05, 
                       verbose=True):
    """ Perform a forward-backward feature selection 
    based on p-value from statsmodels.api.OLS
    Arguments:
        X - pandas.DataFrame with candidate features
        y - list-like with the target
        initial_list - list of features to start with (column names of X)
        threshold_in - include a feature if its p-value < threshold_in
        threshold_out - exclude a feature if its p-value > threshold_out
        verbose - whether to print the sequence of inclusions and exclusions
    Returns: list of selected features 
    Always set threshold_in < threshold_out to avoid infinite looping.
    See https://en.wikipedia.org/wiki/Stepwise_regression for the details
    """
    included = list(initial_list)
    while True:
        changed=False
        # forward step
        excluded = list(set(X.columns)-set(included))
        new_pval = pd.Series(index=excluded)
        for new_column in excluded:
            model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included+[new_column]]))).fit()
            new_pval[new_column] = model.pvalues[new_column]
        best_pval = new_pval.min()
        if best_pval < threshold_in:
            best_feature = new_pval.idxmin()
            included.append(best_feature)
            changed=True
            if verbose:
                print('Add  {:30} with p-value {:.6}'.format(best_feature, best_pval))

        # backward step
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included]))).fit()
        # use all coefs except intercept
        pvalues = model.pvalues.iloc[1:]
        worst_pval = pvalues.max() # null if pvalues is empty
        if worst_pval > threshold_out:
            changed=True
            worst_feature = pvalues.argmax()
            included.remove(worst_feature)
            if verbose:
                print('Drop {:30} with p-value {:.6}'.format(worst_feature, worst_pval))
        if not changed:
            break
    return included

# %%
result = stepwise_selection(df_ohe, target.log_price, verbose=True)
print('resulting features:')
print(result)
# Out:
# Add  grade                          with p-value 0.0
# Add  sqft_basement                  with p-value 0.0
# Add  lat                            with p-value 0.0
# Add  sqft_living                    with p-value 0.0
# Add  yr_built                       with p-value 0.0
# Drop sqft_basement                  with p-value 0.140685
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:43: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
# Add  age_home                       with p-value 0.0
# Add  view                           with p-value 1.16942e-241
# Add  zipcode_98004                  with p-value 3.28212e-268
# Add  zipcode_98155                  with p-value 2.05883e-139
# Add  zipcode_98133                  with p-value 1.0897e-133
# Add  zipcode_98040                  with p-value 2.00349e-132
# Add  zipcode_98112                  with p-value 2.25981e-119
# Add  zipcode_98028                  with p-value 3.11381e-108
# Add  condition                      with p-value 2.15084e-100
# Add  sqft_living15_trans            with p-value 6.2298e-94
# Add  floors                         with p-value 3.23661e-98
# Add  zipcode_98019                  with p-value 4.06581e-95
# Add  zipcode_98039                  with p-value 1.19576e-86
# Add  zipcode_98168                  with p-value 4.55209e-86
# Add  waterfront                     with p-value 3.17167e-85
# Add  zipcode_98011                  with p-value 5.79945e-85
# Add  zipcode_98072                  with p-value 1.61167e-91
# Add  zipcode_98034                  with p-value 2.08795e-98
# Add  zipcode_98077                  with p-value 1.51212e-112
# Add  zipcode_98125                  with p-value 9.54661e-105
# Add  zipcode_98177                  with p-value 2.43546e-102
# Add  zipcode_98022                  with p-value 1.15977e-91
# Add  zipcode_98178                  with p-value 5.09842e-82
# Add  zipcode_98014                  with p-value 3.42571e-79
# Add  sqft_lot                       with p-value 4.25037e-64
# Add  bathrooms                      with p-value 7.42757e-53
# Add  sqft_above_trans               with p-value 2.12372e-50
# Add  zipcode_98052                  with p-value 1.39374e-58
# Drop floors                         with p-value 0.0719444
# Add  zipcode_98053                  with p-value 6.32193e-76
# Add  zipcode_98116                  with p-value 1.22245e-53
# Add  zipcode_98136                  with p-value 3.86444e-51
# Add  zipcode_98119                  with p-value 5.95958e-52
# Add  zipcode_98074                  with p-value 1.43891e-39
# Add  zipcode_98055                  with p-value 4.74729e-40
# Add  zipcode_98109                  with p-value 1.20353e-37
# Add  zipcode_98010                  with p-value 8.20793e-36
# Add  zipcode_98058                  with p-value 6.33683e-32
# Add  zipcode_98106                  with p-value 7.80705e-30
# Add  zipcode_98108                  with p-value 2.85116e-28
# Add  zipcode_98056                  with p-value 1.50036e-27
# Add  zipcode_98188                  with p-value 4.60301e-28
# Add  zipcode_98146                  with p-value 4.82873e-28
# Add  zipcode_98031                  with p-value 6.69269e-26
# Add  zipcode_98102                  with p-value 1.57837e-24
# Add  zipcode_98122                  with p-value 4.36669e-26
# Add  zipcode_98105                  with p-value 9.09351e-28
# Add  zipcode_98006                  with p-value 1.85456e-27
# Add  zipcode_98199                  with p-value 7.96155e-31
# Add  zipcode_98032                  with p-value 2.91101e-20
# Add  zipcode_98198                  with p-value 3.29884e-21
# Add  sqft_basement                  with p-value 1.05364e-20
# Add  yr_renovated                   with p-value 2.99876e-18
# Add  floors                         with p-value 5.06118e-15
# Add  zipcode_98042                  with p-value 1.23496e-13
# Add  zipcode_98065                  with p-value 5.5856e-14
# Add  zipcode_98030                  with p-value 5.12259e-14
# Add  zipcode_98059                  with p-value 5.98916e-15
# Add  zipcode_98023                  with p-value 1.51502e-10
# Add  zipcode_98118                  with p-value 1.80165e-11
# Add  long                           with p-value 1.68478e-09
# Add  zipcode_98148                  with p-value 1.65413e-10
# Add  zipcode_98029                  with p-value 9.29815e-09
# Add  zipcode_98027                  with p-value 4.20206e-09
# Add  zipcode_98003                  with p-value 3.52841e-08
# Add  zipcode_98002                  with p-value 9.36977e-09
# Add  zipcode_98166                  with p-value 2.11095e-09
# Add  zipcode_98005                  with p-value 2.34495e-07
# Add  bedrooms                       with p-value 1.08856e-06
# Add  zipcode_98144                  with p-value 4.65512e-06
# Add  zipcode_98107                  with p-value 3.69545e-06
# Add  zipcode_98103                  with p-value 8.17109e-05
# Add  sqft_living15                  with p-value 0.000568457
# Add  sqft_above                     with p-value 2.3715e-05
# Add  zipcode_98092                  with p-value 0.00105263
# Add  zipcode_98115                  with p-value 0.00125376
# Add  zipcode_98024                  with p-value 0.00678902
# Add  zipcode_98126                  with p-value 0.00659107
# Add  zipcode_98117                  with p-value 0.000253541
# Add  zipcode_98033                  with p-value 4.19103e-07
# Drop zipcode_98118                  with p-value 0.161856
# Add  zipcode_98008                  with p-value 1.66684e-07
# Drop zipcode_98166                  with p-value 0.163521
# Add  zipcode_98007                  with p-value 2.92758e-07
# Drop zipcode_98024                  with p-value 0.191136
# Add  zipcode_98075                  with p-value 1.4077e-09
# Drop zipcode_98065                  with p-value 0.656388
# Add  zipcode_98118                  with p-value 1.05242e-09
# Drop long                           with p-value 0.846035
# Add  zipcode_98070                  with p-value 1.16044e-08
# Drop zipcode_98106                  with p-value 0.647911
# Add  zipcode_98166                  with p-value 0.00072525
# Drop zipcode_98108                  with p-value 0.350295
# Add  long                           with p-value 2.39574e-05
# Drop zipcode_98125                  with p-value 0.835851
# Add  zipcode_98106                  with p-value 0.00183047
# Drop zipcode_98146                  with p-value 0.886039
# Drop zipcode_98056                  with p-value 0.842249
# Drop zipcode_98177                  with p-value 0.581756
# resulting features:
# ['grade', 'lat', 'sqft_living', 'yr_built', 'age_home', 'view', 'zipcode_98004', 'zipcode_98155', 'zipcode_98133', 'zipcode_98040', 'zipcode_98112', 'zipcode_98028', 'condition', 'sqft_living15_trans', 'zipcode_98019', 'zipcode_98039', 'zipcode_98168', 'waterfront', 'zipcode_98011', 'zipcode_98072', 'zipcode_98034', 'zipcode_98077', 'zipcode_98022', 'zipcode_98178', 'zipcode_98014', 'sqft_lot', 'bathrooms', 'sqft_above_trans', 'zipcode_98052', 'zipcode_98053', 'zipcode_98116', 'zipcode_98136', 'zipcode_98119', 'zipcode_98074', 'zipcode_98055', 'zipcode_98109', 'zipcode_98010', 'zipcode_98058', 'zipcode_98188', 'zipcode_98031', 'zipcode_98102', 'zipcode_98122', 'zipcode_98105', 'zipcode_98006', 'zipcode_98199', 'zipcode_98032', 'zipcode_98198', 'sqft_basement', 'yr_renovated', 'floors', 'zipcode_98042', 'zipcode_98030', 'zipcode_98059', 'zipcode_98023', 'zipcode_98148', 'zipcode_98029', 'zipcode_98027', 'zipcode_98003', 'zipcode_98002', 'zipcode_98005', 'bedrooms', 'zipcode_98144', 'zipcode_98107', 'zipcode_98103', 'sqft_living15', 'sqft_above', 'zipcode_98092', 'zipcode_98115', 'zipcode_98126', 'zipcode_98117', 'zipcode_98033', 'zipcode_98008', 'zipcode_98007', 'zipcode_98075', 'zipcode_98118', 'zipcode_98070', 'zipcode_98166', 'long', 'zipcode_98106']

# %% [markdown]
# ### New Model after removing p-values through stepwise

# %%
#X = df_ohe[result]
X = df_ohe.values
y = data_log.log_price
Xconst = sm.add_constant(X)

model = sm.OLS(y, Xconst, hasconst= True)
multiple_model_fitted = model.fit()
print(multiple_model_fitted.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_price   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.881
# Method:                 Least Squares   F-statistic:                     1858.
# Date:                Mon, 30 Mar 2020   Prob (F-statistic):               0.00
# Time:                        15:37:13   Log-Likelihood:                -7573.9
# No. Observations:               21534   AIC:                         1.532e+04
# Df Residuals:                   21447   BIC:                         1.602e+04
# Df Model:                          86
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.139e-05   6.47e-06     -9.494      0.000   -7.41e-05   -4.87e-05
# x1            -0.0164      0.003     -4.831      0.000      -0.023      -0.010
# x2             0.0664      0.006     11.747      0.000       0.055       0.078
# x3             0.0002   1.13e-05     14.097      0.000       0.000       0.000
# x4          1.177e-06   8.24e-08     14.280      0.000    1.02e-06    1.34e-06
# x5            -0.0892      0.007    -12.907      0.000      -0.103      -0.076
# x56            0.9288      0.053     17.433      0.000       0.824       1.033
# x57            0.5492      0.071      7.715      0.000       0.410       0.689
# x58            0.0953      0.028      3.424      0.001       0.041       0.150
# x59            1.4533      0.059     24.554      0.000       1.337       1.569
# x60            1.1592      0.055     20.893      0.000       1.050       1.268
# x61            1.4118      0.057     24.801      0.000       1.300       1.523
# x62            0.4167      0.041     10.112      0.000       0.336       0.497
# x63            1.1898      0.057     20.797      0.000       1.078       1.302
# x64            0.4412      0.045      9.723      0.000       0.352       0.530
# x65            1.4909      0.059     25.322      0.000       1.376       1.606
# x66            1.6281      0.052     31.143      0.000       1.526       1.731
# x67            1.1673      0.056     20.704      0.000       1.057       1.278
# x68            1.1133      0.046     24.240      0.000       1.023       1.203
# x69            1.1137      0.057     19.500      0.000       1.002       1.226
# x70            0.6525      0.040     16.264      0.000       0.574       0.731
# x71            1.4586      0.056     26.219      0.000       1.350       1.568
# x72            1.2110      0.050     24.390      0.000       1.114       1.308
# x73            0.6659      0.061     10.936      0.000       0.547       0.785
# x74            0.7698      0.042     18.228      0.000       0.687       0.853
# x75            0.4158      0.063      6.614      0.000       0.293       0.539
# x76            1.0092      0.043     23.315      0.000       0.924       1.094
# x77            0.9813      0.046     21.242      0.000       0.891       1.072
# x78            0.3028      0.039      7.844      0.000       0.227       0.378
# x79            0.1281      0.052      2.445      0.015       0.025       0.231
# x80            0.3609      0.065      5.522      0.000       0.233       0.489
# x81            0.3836      0.035     10.865      0.000       0.314       0.453
# x82           -0.0330      0.037     -0.884      0.377      -0.106       0.040
# x83            0.6147      0.066      9.371      0.000       0.486       0.743
# x84            0.1211      0.039      3.143      0.002       0.046       0.197
# x85            0.0508      0.040      1.284      0.199      -0.027       0.128
# x86            0.0060      0.030      0.201      0.840      -0.053       0.065
# x87            1.2095      0.054     22.309      0.000       1.103       1.316
# ==============================================================================
# Omnibus:                     1663.605   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7476.443
# Skew:                          -0.252   Prob(JB):                         0.00
# Kurtosis:                       5.842   Cond. No.                     3.71e+20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.99e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Normality Check

# %% [markdown]
# #### Find residiuals and check distributions

# %%
residuals = multiple_model_fitted.resid
display(plt.hist(residuals))

fig = sm.graphics.qqplot(residuals, dist=stats.norm, line='45', fit=True)
display(fig.show())
# Out:
# (array([1.0000e+00, 5.0000e+00, 1.2000e+01, 8.3000e+01, 6.9400e+02,
#         5.4630e+03, 1.2929e+04, 2.1430e+03, 1.7800e+02, 2.6000e+01]),
#  array([-3.26219379, -2.74298011, -2.22376643, -1.70455274, -1.18533906,
#         -0.66612538, -0.14691169,  0.37230199,  0.89151568,  1.41072936,
#          1.92994304]),
#  <a list of 10 Patch objects>)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-5128c7ad7d95> in <module>()
#       2 display(plt.hist(residuals))
#       3
# ----> 4 fig = sm.graphics.qqplot(residuals, dist=stats.norm, line='45', fit=True)
#       5 display(fig.show())
#
# AttributeError: 'module' object has no attribute 'norm'

# %%
fig2=plt.plot(residuals, 'o', ls='None')
l = plt.axhline(y=0, color='r')
plt.ylabel('Standardized Residual')
plt.xlabel('Observation Number')
print(fig2)
# Out:
# [<matplotlib.lines.Line2D object at 0x1c24fb77d0>]

# %% [markdown]
# #### Standard normal distribution. 97% of residual values fall between 1 standard deviation.

# %% [markdown]
# ### 80/20 Train Test Split to find best fit line

# %%
#change df_ohe to a numpy array for training
x_array = df_ohe.to_numpy()

#change housing price serie to a numpy array
y_array = data_log.log_price.to_numpy()

# %%
#split data into 80% test and 20% train
X_train, X_test, y_train, y_test = train_test_split(x_array, y_array, test_size=0.2, random_state=50)

# %% [markdown]
# #### MixMaxScaler() to fit and transform X_train and transform X_test

# %%
scale = MinMaxScaler()
X_train_transformed = scale.fit_transform(X_train)
X_test_transformed = scale.transform(X_test)

# %% [markdown]
# #### Build a Ridge, Lasso and regular linear regression model

# %%
 # Note that in scikit-learn, the regularization parameter is denoted by alpha (and not lambda)
ridge = Ridge(alpha=0.5)
ridge.fit(X_train_transformed, y_train)

lasso = Lasso(alpha=0.5)
lasso.fit(X_train_transformed, y_train)

lin = LinearRegression()
lin.fit(X_train_transformed, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
display(X_train_transformed.shape)
display(X_test_transformed.shape)
# Out:
# (17227, 87)
# (4307, 87)

# %%
# Generate preditions for training and test sets
y_h_ridge_train = ridge.predict(X_train_transformed)
y_h_ridge_test = ridge.predict(X_test_transformed)

y_h_lasso_train = np.reshape(lasso.predict(X_train_transformed), (17227, 1))
y_h_lasso_test = np.reshape(lasso.predict(X_test_transformed), (4307, 1))

y_h_lin_train = lin.predict(X_train_transformed)
y_h_lin_test = lin.predict(X_test_transformed)

# %% [markdown]
# #### RSS for training and test sets for each of the three models:

# %%
print('Train Error Ridge Model', np.sum((y_train - y_h_ridge_train)**2))
print('Test Error Ridge Model', np.sum((y_test - y_h_ridge_test)**2))
print('\n')

print('Train Error Lasso Model', np.sum((y_train - y_h_lasso_train)**2))
print('Test Error Lasso Model', np.sum((y_test - y_h_lasso_test)**2))
print('\n')

print('Train Error Unpenalized Linear Model', np.sum((y_train - lin.predict(X_train_transformed))**2))
print('Test Error Unpenalized Linear Model', np.sum((y_test - lin.predict(X_test_transformed))**2))
# Out:
# ('Train Error Ridge Model', 561.9210443116974)
# ('Test Error Ridge Model', 146.4904900636864)
#
#
# ('Train Error Lasso Model', 81976179.47360758)
# ('Test Error Lasso Model', 5195639.59524523)
#
#
# ('Train Error Unpenalized Linear Model', 560.7007058733319)
# ('Test Error Unpenalized Linear Model', 145.97696009050532)

# %% [markdown]
# #### Best fit line

# %%
# To find the best fit line:
lr = LinearRegression()
model = lr.fit(X_train, y_train)

# coefficients (m slope)
m = lr.coef_

# y-intercept b
b = lr.intercept_

# %% [markdown]
# ### Cross-Validation

# %%
cv_5_results  = (cross_val_score(lr, X_train, y_train, cv=5,  scoring='r2'))
cv_5_results.mean()
# Out:
# 0.8755449878371918

# %%
linreg = LinearRegression()
linreg.fit(X_train, y_train)

y_hat_train = linreg.predict(X_train)
y_hat_test = linreg.predict(X_test)

# %% [markdown]
# ### Test for Underfitting and Overtfitting

# %%
from sklearn.metrics import mean_squared_error

train_mse = mean_squared_error(y_train, y_hat_train)
test_mse = mean_squared_error(y_test, y_hat_test)
print('Train Mean Squarred Error:', train_mse)
print('Test Mean Squarred Error:', test_mse)

# ('Train Mean Squarred Error:', 0.11743989775683308)
# ('Test Mean Squarred Error:', 0.12234187396714999)

# Results do not show big difference between the train and test MSE.
# Out:
# ('Train Mean Squarred Error:', 0.11743989775683308)
# ('Test Mean Squarred Error:', 0.12234187396714999)

# %%
#create a residual map

#Instantiate the linear model and visualizer
model = LinearRegression()
visualizer = ResidualsPlot(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.poof()                 # Finalize and render the figure
